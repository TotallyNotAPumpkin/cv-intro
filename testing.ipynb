# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from lane_detection import detect_lines, draw_lines, get_slopes_intercepts, detect_lanes, draw_lanes
from lane_following import get_lane_center, videoDetection, videoDetectionFrames, draw_lane_center, recommend_direction

# %%
# TO DO: 
# test detect_lines check
# test detect_lanes
# test get_lane_center
# test draw_lane_center
# test draw_lanes

# %%
stupidFuckingImg = cv2.imread('2174.jpg')
copyOfFucker = np.copy(stupidFuckingImg)

# %%
# linesOfBitch = detect_lines(copyOfFucker, 50, 70, 3, 200, 10)
linesOfBitch = [[0, 400, 1000, 400], [0, 600, 1000, 600]]
linesOfBitch
# Out:
# [[0, 400, 1000, 400], [0, 600, 1000, 600]]

# %%
linesImage = np.copy(copyOfFucker)
plt.imshow(draw_lines(linesImage, linesOfBitch))

# %%
s, l = get_slopes_intercepts(copyOfFucker, linesOfBitch)
print(f'Slopes: {s} - x-Intercepts: {l}')
# Out:
# Slopes: [-0.0, -0.0] - x-Intercepts: [6800.0, 4800.0]

# %%
detect_lanes(copyOfFucker, linesOfBitch)
# Out:
# []
